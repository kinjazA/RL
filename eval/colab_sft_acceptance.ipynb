# %% [markdown]
# # SFT Acceptance: Base vs SFT
#
# Run this notebook with a Colab T4 GPU. The evaluation questions and scoring points are never included in the model prompt.

# %%
# In Colab, add a Secret named GITHUB_TOKEN with read access to this private repo.
# The token is passed to git without being printed in notebook output.
from google.colab import userdata
import subprocess

github_token = userdata.get('GITHUB_TOKEN')
if not github_token:
    raise RuntimeError('Add a Colab Secret named GITHUB_TOKEN, grant this notebook access, then rerun this cell.')

repo_url = f'https://x-access-token:{github_token}@github.com/kinjazA/RL.git'
subprocess.run(['git', 'clone', '--depth', '1', repo_url, '/content/RL'], check=True)
# %cd /content/RL
# !pip -q install --upgrade 'transformers==4.57.1' 'peft==0.18.1' 'accelerate==1.11.0' 'bitsandbytes==0.48.2' sentencepiece

# %%
# !python eval/compare_base_sft.py \
  --base_model Qwen/Qwen2.5-3B \
  --sft_adapter Shawnno/qwen2.5-3b-interview-sft-lora \
  --output_dir eval/results/sft_acceptance_v1

# %%
# Optional RM scoring. Fill these values only after confirming the RM training base,
# adapter path, and the exact prompt format used by the RM trainer.
# !python eval/compare_base_sft.py \
#   --base_model Qwen/Qwen2.5-3B \
#   --sft_adapter Shawnno/qwen2.5-3b-interview-sft-lora \
#   --rm_model <RM_BASE_OR_FULL_MODEL> \
#   --rm_adapter <RM_ADAPTER_IF_ANY> \
#   --rm_input_format question_answer \
#   --output_dir eval/results/sft_acceptance_with_rm

# %%
from pathlib import Path
print(Path('eval/results/sft_acceptance_v1/summary.md').read_text(encoding='utf-8'))
# !zip -qr sft_acceptance_v1.zip eval/results/sft_acceptance_v1
from google.colab import files
files.download('sft_acceptance_v1.zip')
