# %% [markdown]
# # Base vs SFT Model Comparison
# Compare Qwen2.5-3B-Instruct **before** and **after** SFT fine-tuning on interview Q&A.
#
# Each question runs twice on the same model by toggling LoRA layers on/off — no double VRAM.

# %%
# @title 1. Setup
# !rm -rf /content/RL
# !git clone https://github.com/kinjazA/RL.git /content/RL
# %cd /content/RL
# !pip install -q -r requirements_sft.txt

# %%
# @title 2. Compare BASE vs SFT
# !python -m sft.compare --adapter_path Shawnno/RL-sft-adapter
